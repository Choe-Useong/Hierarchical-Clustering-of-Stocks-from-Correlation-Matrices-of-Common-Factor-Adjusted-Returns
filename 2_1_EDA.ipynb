# %%
# EDA of item__로그수익률.parquet

# 1. 데이터 기본 구조 EDA

import pandas as pd

df = pd.read_parquet("item__로그수익률 (1).parquet")

# 관측치 수, 변수 수
n_rows, n_cols = df.shape
print("관측치 수:", n_rows)
print("변수 수:", n_cols)

# 컬럼 목록 확인
print("컬럼 목록:")
print(df.columns.tolist())

df.head()
# Out:
# 관측치 수: 1227
# 변수 수: 6415
# 컬럼 목록:
# [Timestamp('2000-01-04 00:00:00'), Timestamp('2000-01-05 00:00:00'), Timestamp('2000-01-06 00:00:00'), Timestamp('2000-01-07 00:00:00'), Timestamp('2000-01-10 00:00:00'), Timestamp('2000-01-11 00:00:00'), Timestamp('2000-01-12 00:00:00'), Timestamp('2000-01-13 00:00:00'), Timestamp('2000-01-14 00:00:00'), Timestamp('2000-01-17 00:00:00'), Timestamp('2000-01-18 00:00:00'), Timestamp('2000-01-19 00:00:00'), Timestamp('2000-01-20 00:00:00'), Timestamp('2000-01-21 00:00:00'), Timestamp('2000-01-24 00:00:00'), Timestamp('2000-01-25 00:00:00'), Timestamp('2000-01-26 00:00:00'), Timestamp('2000-01-27 00:00:00'), Timestamp('2000-01-28 00:00:00'), Timestamp('2000-01-31 00:00:00'), Timestamp('2000-02-01 00:00:00'), Timestamp('2000-02-02 00:00:00'), Timestamp('2000-02-03 00:00:00'), Timestamp('2000-02-07 00:00:00'), Timestamp('2000-02-08 00:00:00'), Timestamp('2000-02-09 00:00:00'), Timestamp('2000-02-10 00:00:00'), Timestamp('2000-02-11 00:00:00'), Timestamp('2000-02-14 00:00:00'), Timestamp('2000-02-15 00:00:00'), Timestamp('2000-02-16 00:00:00'), Timestamp('2000-02-17 00:00:00'), Timestamp('2000-02-18 00:00:00'), Timestamp('2000-02-21 00:00:00'), Timestamp('2000-02-22 00:00:00'), Timestamp('2000-02-23 00:00:00'), Timestamp('2000-02-24 00:00:00'), Timestamp('2000-02-25 00:00:00'), Timestamp('2000-02-28 00:00:00'), Timestamp('2000-02-29 00:00:00'), Timestamp('2000-03-02 00:00:00'), Timestamp('2000-03-03 00:00:00'), Timestamp('2000-03-06 00:00:00'), Timestamp('2000-03-07 00:00:00'), Timestamp('2000-03-08 00:00:00'), Timestamp('2000-03-09 00:00:00'), Timestamp('2000-03-10 00:00:00'), Timestamp('2000-03-13 00:00:00'), Timestamp('2000-03-14 00:00:00'), Timestamp('2000-03-15 00:00:00'), Timestamp('2000-03-16 00:00:00'), Timestamp('2000-03-17 00:00:00'), Timestamp('2000-03-20 00:00:00'), Timestamp('2000-03-21 00:00:00'), Timestamp('2000-03-22 00:00:00'), Timestamp('2000-03-23 00:00:00'), Timestamp('2000-03-24 00:00:00'), Timestamp('2000-03-27 00:00:00'), Timestamp('2000-03-28 00:00:00'), Timestamp('2000-03-29 00:00:00'), Timestamp('2000-03-30 00:00:00'), Timestamp('2000-03-31 00:00:00'), Timestamp('2000-04-03 00:00:00'), Timestamp('2000-04-04 00:00:00'), Timestamp('2000-04-06 00:00:00'), Timestamp('2000-04-07 00:00:00'), Timestamp('2000-04-10 00:00:00'), Timestamp('2000-04-11 00:00:00'), Timestamp('2000-04-12 00:00:00'), Timestamp('2000-04-14 00:00:00'), Timestamp('2000-04-17 00:00:00'), Timestamp('2000-04-18 00:00:00'), Timestamp('2000-04-19 00:00:00'), Timestamp('2000-04-20 00:00:00'), Timestamp('2000-04-21 00:00:00'), Timestamp('2000-04-24 00:00:00'), Timestamp('2000-04-25 00:00:00'), Timestamp('2000-04-26 00:00:00'), Timestamp('2000-04-27 00:00:00'), Timestamp('2000-04-28 00:00:00'), Timestamp('2000-05-02 00:00:00'), Timestamp('2000-05-03 00:00:00'), Timestamp('2000-05-04 00:00:00'), Timestamp('2000-05-08 00:00:00'), Timestamp('2000-05-09 00:00:00'), Timestamp('2000-05-10 00:00:00'), Timestamp('2000-05-12 00:00:00'), Timestamp('2000-05-15 00:00:00'), Timestamp('2000-05-16 00:00:00'), Timestamp('2000-05-17 00:00:00'), Timestamp('2000-05-18 00:00:00'), Timestamp('2000-05-19 00:00:00'), Timestamp('2000-05-22 00:00:00'), Timestamp('2000-05-23 00:00:00'), Timestamp('2000-05-24 00:00:00'), Timestamp('2000-05-25 00:00:00'), Timestamp('2000-05-26 00:00:00'), Timestamp('2000-05-29 00:00:00'), Timestamp('2000-05-30 00:00:00'), Timestamp('2000-05-31 00:00:00'), Timestamp('2000-06-01 00:00:00'), Timestamp('2000-06-02 00:00:00'), Timestamp('2000-06-05 00:00:00'), Timestamp('2000-06-07 00:00:00'), Timestamp('2000-06-08 00:00:00'), Timestamp('2000-06-09 00:00:00'), Timestamp('2000-06-12 00:00:00'), Timestamp('2000-06-13 00:00:00'), Timestamp('2000-06-14 00:00:00'), Timestamp('2000-06-15 00:00:00'), Timestamp('2000-06-16 00:00:00'), Timestamp('2000-06-19 00:00:00'), Timestamp('2000-06-20 00:00:00'), Timestamp('2000-06-21 00:00:00'), Timestamp('2000-06-22 00:00:00'), Timestamp('2000-06-23 00:00:00'), Timestamp('2000-06-26 00:00:00'), Timestamp('2000-06-27 ...
#                      2000-01-04  2000-01-05  2000-01-06  2000-01-07  \
# Symbol  Symbol Name
# A005930 삼성전자                NaN   -0.090738    0.007143   -0.014337
# A000660 SK하이닉스              NaN   -0.108603   -0.053345   -0.009175
# A207940 삼성바이오로직스            NaN         NaN         NaN         NaN
# A373220 LG에너지솔루션            NaN         NaN         NaN         NaN
# A005380 현대차                 NaN    0.004819   -0.054334    0.030002
#
#                      2000-01-10  2000-01-11  2000-01-12  2000-01-13  \
# Symbol  Symbol Name
# A005930 삼성전자           0.040678    0.000000   -0.008703   -0.001750
# A000660 SK하이닉스        -0.009260    0.036534    0.013363    0.039049
# A207940 삼성바이오로직스            NaN         NaN         NaN         NaN
# A373220 LG에너지솔루션            NaN         NaN         NaN         NaN
# A005380 현대차           -0.014889    0.000000   -0.027885    0.002567
#
#                      2000-01-14  2000-01-17  ...  2025-12-24  2025-12-26  \
# Symbol  Symbol Name                          ...
# A005930 삼성전자           0.020798    0.045272  ...   -0.003594    0.051743
# A000660 SK하이닉스        -0.030238    0.088107  ...    0.006826    0.018535
# A207940 삼성바이오로직스            NaN         NaN  ...   -0.017004    0.000591
# A373220 LG에너지솔루션            NaN         NaN  ...    0.006423   -0.018088
# A005380 현대차           -0.052644    0.000000  ...    0.006944   -0.010435
#
#                      2025-12-29  2025-12-30  2026-01-02  2026-01-05  \
# Symbol  Symbol Name
# A005930 삼성전자           0.021142    0.003342    0.069271    0.072049
# A000660 SK하이닉스         0.066207    0.017041    0.039162    0.027678
# A207940 삼성바이오로직스       0.008240   -0.006469   -0.007105    0.017668
# A373220 LG에너지솔루션      -0.009168   -0.030731   -0.020563    0.028671
# A005380 현대차            0.025886    0.010170    0.006723    0.019901
#
#                      2026-01-06  2026-01-07  2026-01-08  2026-01-09
# Symbol  Symbol Name
# A005930 삼성전자           0.005776    0.015006   -0.015726    0.001440
# A000660 SK하이닉스         0.042200    0.021799    0.018692   -0.016000
# A207940 삼성바이오로직스       0.004659    0.026378    0.064645   -0.003720
# A373220 LG에너지솔루션       0.017345   -0.020041   -0.012220   -0.008230
# A005380 현대차            0.011429    0.129261   -0.028946    0.072218
#
# [5 rows x 6415 columns]

# %%
# 2. 시간 관련 EDA

df.columns = pd.to_datetime(df.columns)

# 전체 기간 범위
start_date = df.columns.min()
end_date = df.columns.max()

print("전체 기간 범위:")
print("시작일:", start_date)
print("종료일:", end_date)

# 연도 추출
years = df.columns.year

# 연도별 데이터 개수
year_counts = pd.Series(years).value_counts().sort_index()

print("연도별 데이터 개수:")
print(year_counts)

# 연도별 데이터 개수 그래프

import matplotlib.pyplot as plt; plt.show()

year_counts.plot(kind="bar", title="YearCounts")
# Out:
# 전체 기간 범위:
# 시작일: 2000-01-04 00:00:00
# 종료일: 2026-01-09 00:00:00
# 연도별 데이터 개수:
# 2000    241
# 2001    246
# 2002    244
# 2003    247
# 2004    249
# 2005    249
# 2006    247
# 2007    246
# 2008    248
# 2009    253
# 2010    251
# 2011    248
# 2012    248
# 2013    247
# 2014    245
# 2015    248
# 2016    246
# 2017    243
# 2018    244
# 2019    246
# 2020    248
# 2021    248
# 2022    246
# 2023    245
# 2024    244
# 2025    242
# 2026      6
# Name: count, dtype: int64
# <Axes: title={'center': 'YearCounts'}>

# %%
# 2015년 제도 변경 전·후 비교

period_2015 = pd.Series(
    ["Prior to 2015" if y < 2015 else "Since 2015" for y in years]
).value_counts()

print("2015년 제도 변경 전·후 컬럼(날짜) 개수:")
print(period_2015)

# 제도 변경 전·후 그래프
period_2015.plot(kind="bar", title="period 2015")
# Out:
# 2015년 제도 변경 전·후 컬럼(날짜) 개수:
# Prior to 2015    3709
# Since 2015       2706
# Name: count, dtype: int64
# <Axes: title={'center': 'period 2015'}>

# %%
# 3. 결측치 EDA

# 종목별 결측치 비율
missing_by_item = df.isna().mean(axis=1)

print("종목별 결측치 비율 20개:")
print(missing_by_item.sort_values(ascending=False).head(20))


# 날짜별 결측치 비율
missing_by_date = df.isna().mean(axis=0)

print("\n날짜별 결측치 비율 20개:")
print(missing_by_date.sort_values(ascending=False).head(20))
# Out:
# 종목별 결측치 비율 20개:
# Symbol   Symbol Name
# A000090  두산상사           1.0
# A000130  한일은행           1.0
# A000160  대한중석           1.0
# A000170  LG금속           1.0
# A016690  신세계종합금융        1.0
# A017070  호승             1.0
# A017110  고려종합금융         1.0
# A019230  신비             1.0
# A019380  신강제지           1.0
# A020100  태일전자           1.0
# A021170  고려석유화학         1.0
# A000330  두산백화           1.0
# A000450  한주통산           1.0
# A000510  태화             1.0
# A000570  금호건설           1.0
# A000600  삼화실업           1.0
# A000730  서울교통공사         1.0
# A000870  전진산업           1.0
# A000930  한화기계           1.0
# A001090  동서증권           1.0
# dtype: float64
#
# 날짜별 결측치 비율 20개:
# 2000-01-04    1.000000
# 2005-06-24    0.454768
# 2005-07-19    0.454768
# 2005-07-18    0.454768
# 2005-06-21    0.454768
# 2005-06-29    0.454768
# 2005-06-17    0.454768
# 2005-06-16    0.454768
# 2005-06-22    0.454768
# 2005-06-20    0.454768
# 2005-06-23    0.454768
# 2005-06-27    0.454768
# 2005-06-30    0.454768
# 2005-06-28    0.454768
# 2005-06-13    0.453953
# 2005-06-14    0.453953
# 2005-05-23    0.453953
# 2005-05-20    0.453953
# 2005-05-18    0.453953
# 2005-05-19    0.453953
# dtype: float64

# %%
# 결측치 비율 0.3 이상인 종목 선택
high_missing_items = missing_by_item[missing_by_item >= 0.3]

# 갯수 출력
print("결측치 비율 ≥ 0.3인 종목 수:", len(high_missing_items))

# 종목 이름과 비율 출력
print("\n결측치 비율 ≥ 0.3인 종목 리스트:")
print(high_missing_items.sort_values(ascending=False))
# Out:
# 결측치 비율 ≥ 0.3인 종목 수: 630
#
# 결측치 비율 ≥ 0.3인 종목 리스트:
# Symbol   Symbol Name
# A029890  현대반도체          1.000000
# A021170  고려석유화학         1.000000
# A017070  호승             1.000000
# A016690  신세계종합금융        1.000000
# A016680  태흥피혁공업         1.000000
#                           ...
# A085310  엔케이            0.309587
# A051600  한전KPS          0.305690
# A092440  기신정기           0.300546
# A044450  KSS해운          0.300234
# A094280  효성ITX          0.300078
# Length: 630, dtype: float64

# %%
# 결측치 비율 0.3 이상인 날짜 선택
high_missing_dates = missing_by_date[missing_by_date >= 0.3]

# 갯수 출력
print("결측치 비율 ≥ 0.3인 날짜 수:", len(high_missing_dates))

# 날짜와 비율 출력
print("\n결측치 비율 ≥ 0.3인 날짜 리스트:")
print(high_missing_dates.sort_values(ascending=False))
# Out:
# 결측치 비율 ≥ 0.3인 날짜 수: 6415
#
# 결측치 비율 ≥ 0.3인 날짜 리스트:
# 2000-01-04    1.000000
# 2005-06-24    0.454768
# 2005-07-19    0.454768
# 2005-07-18    0.454768
# 2005-06-21    0.454768
#                 ...
# 2025-08-07    0.330888
# 2025-08-13    0.330888
# 2025-08-14    0.330888
# 2025-05-26    0.330073
# 2025-05-23    0.330073
# Length: 6415, dtype: float64

# %%
# 4. 수익률 기초 통계

# 전체 수익률 데이터를 1차원 + 결측치 제거
returns = df.values.flatten()
returns = returns[~pd.isna(returns)]

# 기초 통계량 계산
print("수익률 기초 통계:")
print("평균:", returns.mean())
print("중앙값:", pd.Series(returns).median())
print("표준편차:", returns.std())
print("최소값:", returns.min())
print("최대값:", returns.max())
# Out:
# 수익률 기초 통계:
# 평균: -0.00010673928573323377
# 중앙값: 0.0
# 표준편차: 0.03587562727423908
# 최소값: -4.334485689904882
# 최대값: 11.112447898373103

# %%
# 5. 히스토그램

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ±30% 단순수익률 기준 로그수익률 범위 선택
returns_clean = returns[(returns > -0.357) & (returns < 0.262)]

# 히스토그램
plt.figure(figsize=(8,5))  # 그래프 크기 설정
sns.histplot(returns_clean, bins=100, kde=True, color='skyblue')  # 히스토그램
plt.title("Distribution of Log Returns") # 로그수익 분포
plt.xlabel("Log Rate of Return") # 로그수익률
plt.ylabel("Frequency") # 빈도
plt.show()

# %%
# 6. 0 값 비율

# 전체 0 개수
zero_count = (df == 0).sum().sum()  # 각 셀 비교 후 합계

# 전체 데이터 수
total_count = df.size  # 행*열 전체 관측치

# 0 비율 계산
zero_ratio = zero_count / total_count

print("전체 0 값 개수:", zero_count)
print("전체 데이터 개수:", total_count)
print("0 값 비율:", zero_ratio*100,"%")
# Out:
# 전체 0 값 개수: 399632
# 전체 데이터 개수: 7871205
# 0 값 비율: 5.077138760837762 %

# %%
# 7. 로그 수익률 하위 top10
df.stack().sort_values().head(10)
# Out:
# Symbol   Symbol Name
# A009940  대아리드선        2005-04-19   -4.334486
# A009840  갑을           2003-04-07   -4.127134
# A015540  에코바이브        2023-10-27   -3.754979
# A069470  제로원인터랙티브     2010-04-22   -3.628776
# A008320  한국기술산업       2010-03-02   -3.367296
# A093230  이아이디         2025-09-02   -3.326474
# A006150  한메NS         2005-03-29   -3.221226
# A006750  센추리          2005-04-04   -3.220743
# A009890  맥슨텔레콤        2005-04-12   -3.188417
# A004550  대우송도개발       2012-06-13   -3.074375
# dtype: float64

# %%
# 로그 수익률 상위 top 10
df.stack().sort_values().tail(10)
# Out:
# Symbol   Symbol Name
# A063350  팬택앤큐리텔       2007-04-20     0.931558
# A016160  오라바이오틱스      2011-04-20     1.036919
# A005060  대우통신         2002-04-09     1.098612
# A001920  한보철강         2002-03-29     1.098612
# A007050  유리이에스        2009-04-08     1.466337
# A005560  JS전선         2003-04-15     1.658711
# A004230  세신           2009-04-29     1.791759
# A950010  평산차업 KDR     2015-10-27     1.875141
# A018570  선진금속         2002-04-29     2.265314
# A008080  에스와이코퍼레이션    2013-09-11    11.112448
# dtype: float64

# %%
#EDA of kospi.csv

# 1. 기초 통계

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("kospi.csv", index_col=0, parse_dates=True)  # 날짜 -> index

print("기초 통계")
print(df.describe())
# Out:
# 기초 통계
#                 rm
# count  6408.000000
# mean      0.000229
# std       0.014383
# min      -0.128047
# 25%      -0.006028
# 50%       0.000708
# 75%       0.007392
# max       0.112844

# %%
# 2. 코스피 로그 수익률 시계열 그래프
plt.figure(figsize=(12,4))
plt.plot(df.index, df['rm'], color='blue')  # 날짜별 수익률 라인
plt.title("KOSPI rate of retrun") #코스피 수익률
plt.xlabel("date") # 날짜
plt.ylabel("Log Rate of Return") # 로그 수익률
plt.show()

# %%
# 3. 히스토그램
plt.figure(figsize=(6,4))
sns.histplot(df['rm'], bins=50, kde=True, color='green')  # 히스토그램 + KDE
plt.title("KOSPI rate of retrun") # 코스피 수익률
plt.xlabel("Log Rate of Return") # 로그 수익률
plt.show()

# %%
# 4. 이동 표준편차

import numpy as np

# ±30% 확인
threshold = 0.3  # 로그수익률 기준 ±0.3
outliers = df[df['rm'].abs() > threshold]  # 절대값이 0.3 초과인 행
print("±30% 이상 수익률(극단값) 개수:", len(outliers))
print(outliers)

# 이동 표준편차 계산
window = 20  # 20일 이동표준편차
df['volatility'] = df['rm'].rolling(window=window).std()  # rolling std 계산

# 이동 변동성 시각화
plt.figure(figsize=(12,4))
plt.plot(df.index, df['volatility'], color='red')
plt.title("20-day movement volatility") # 20일 이동 변동성
plt.xlabel("date") # 날짜
plt.ylabel("volatility") # 변동성
plt.show()
# Out:
# ±30% 이상 수익률(극단값) 개수: 0
# Empty DataFrame
# Columns: [rm]
# Index: []

# %%
# 5. 연도별 변동성
df['year'] = df.index.year
df['month'] = df.index.month

# 연도별 변동성 평균
annual_vol = df.groupby('year')['rm'].std()
plt.figure(figsize=(8,4))
annual_vol.plot(kind='bar', color='orange')
plt.title("volatility by year") # 연도별 변동성 (표준편차)
plt.xlabel("year") # 연도
plt.ylabel("volatility") # 변동성
plt.show()

# %%
# 월별 변동성 평균
monthly_vol = df.groupby('month')['rm'].std()
plt.figure(figsize=(8,4))
monthly_vol.plot(kind='bar', color='purple')
plt.title("monthly volatility)") # 월별 변동성 (표준편차)
plt.xlabel("month")
plt.ylabel("volatility")
plt.show()

# %%
# 샤프비율 (로그수익률 기준)

import numpy as np

# 로그수익률
returns = df['rm']

# 평균 로그수익률
mean_return = returns.mean()

# 로그수익률 표준편차
std_return = returns.std()

sharpe_ratio = mean_return / std_return

print("샤프비율:", sharpe_ratio)
# Out:
# 샤프비율: 0.015902798629410426

# %%
# 최대 낙폭 (MDD)

# 누적 로그수익률
cum_log_return = returns.cumsum()

# 누적 수익률을 지수화 (실제 수익률 곡선)
cum_return = np.exp(cum_log_return)

# 과거 최고점 계산
running_max = cum_return.cummax()

# Drawdown 계산 (고점 대비 하락률)
drawdown = (cum_return - running_max) / running_max

mdd = drawdown.min()

print("MDD:", mdd)
# Out:
# MDD: -0.5453665130144082
